# %%
paragraph = """
Pakistan's history is deeply rooted in the ancient civilizations that flourished along the Indus River, most notably the Indus Valley Civilization, which dates back to around 2500 BCE and included major urban centers such as Mohenjo-daro and Harappa, known for their advanced urban planning, drainage systems, and trade networks. Over the following millennia, the region that now constitutes Pakistan became a crossroads for numerous cultures, empires, and religions, including the Vedic civilization, the Persian Achaemenid Empire, the campaigns of Alexander the Great, and the rise of Buddhism under the Mauryan Empire, particularly during the reign of Emperor Ashoka. The area later came under the influence of the Kushan Empire, which contributed to the flourishing of Gandhara art and culture, blending Greek, Persian, and Indian artistic traditions. With the arrival of Muslim rule in the eighth century, beginning with Muhammad bin Qasim's conquest of Sindh, the region gradually became integrated into the broader Islamic world, and subsequent centuries saw the establishment of various Muslim dynasties and empires, culminating in the powerful Mughal Empire, which left a lasting architectural and cultural legacy visible in structures such as the Lahore Fort and Shalimar Gardens. During the colonial era, the British East India Company gradually extended its control over the subcontinent, eventually leading to direct British Crown rule following the 1857 rebellion, a period during which political consciousness among Muslims of the region grew substantially. This consciousness gave rise to movements advocating for separate political and cultural rights, most significantly the All-India Muslim League under the leadership of Muhammad Ali Jinnah, who championed the Two-Nation Theory, arguing that Muslims and Hindus constituted distinct nations deserving separate homelands. These efforts culminated in the Lahore Resolution of 1940, which laid the ideological groundwork for the eventual creation of Pakistan. On August 14, 1947, Pakistan emerged as an independent nation through the partition of British India, a process marked by immense human suffering, mass migration, and communal violence as millions of people crossed newly drawn borders. In the decades following independence, Pakistan navigated a complex and often turbulent political journey, marked by periods of civilian democratic governance interspersed with military rule, beginning with General Ayub Khan's takeover in 1958 and followed by subsequent periods of martial law under leaders such as Yahya Khan and later Zia-ul-Haq. The country experienced a significant and traumatic event in 1971 when East Pakistan, following a bitter civil war and Indian military intervention, seceded to become the independent nation of Bangladesh. Pakistan's history since then has been shaped by ongoing struggles for democratic consolidation, tensions with neighboring India particularly over the disputed region of Kashmir, involvement in regional geopolitics including the Soviet-Afghan War and subsequent war on terror, as well as efforts toward economic development and social progress. Throughout its history, Pakistan has maintained a rich cultural identity shaped by its diverse ethnic groups, including Punjabis, Sindhis, Pashtuns, Balochis, and Muhajirs, along with a strong Islamic heritage that continues to influence its social and political institutions to this day.
"""

# %%
import nltk
from nltk.stem import PorterStemmer, SnowballStemmer, WordNetLemmatizer
from nltk.corpus import stopwords

# %%
porterstemmer = PorterStemmer()

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
type(sentences)
# Out:
# list

# %%
# apply stopwords and filter and then apply stemming

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
  
    words = [porterstemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]

    sentences[i] = ' '.join(words)

sentences[i]
# Out:
# 'throughout histori , pakistan maintain rich cultur ident shape divers ethnic group , includ punjabi , sindhi , pashtun , balochi , muhajir , along strong islam heritag continu influenc social polit institut day .'

# %%
snowballstemmer = SnowballStemmer(language='english')

# %%
# apply stopwords and filter and then apply stemming

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
  
    words = [snowballstemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]

    sentences[i] = ' '.join(words)

sentences[i]
# Out:
# 'throughout histori , pakistan maintain rich cultur ident shape diver ethnic group , includ punjabi , sindhi , pashtun , balochi , muhajir , along strong islam heritag continu influenc social polit institut day .'

# %%
wordnetlemmatizer = WordNetLemmatizer()

# %%
# apply stopwords and filter and then apply stemming

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
  
    words = [wordnetlemmatizer.lemmatize(word, pos='v') for word in words if word not in set(stopwords.words('english'))]

    sentences[i] = ' '.join(words)

sentences[i]
# Out:
# 'throughout histori , pakistan maintain rich cultur ident shape diver ethnic group , includ punjabi , sindhi , pashtun , balochi , muhajir , along strong islam heritag continu influenc social polit institut day .'
