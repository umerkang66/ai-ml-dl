# %%
corpus = """
  Hello, Welcome! This is umer, learning NLP.
  To learn it effectively, we need to practice it daily.
  I am using a Udemy course to learn NLP. It is a great course for beginners.
"""

# %% [markdown]
# ## Tokenization
#
# _Tokenization is the process of breaking down text into smaller units called tokens. These tokens can be words, phrases, or even sentences. Tokenization is a crucial step in natural language processing (NLP) as it helps in understanding the structure and meaning of the text._

# %%
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize, TreebankWordTokenizer

# %%
documents = sent_tokenize(corpus)
documents
# Out:
# ['\n  Hello, Welcome!',
#  'This is umer, learning NLP.',
#  'To learn it effectively, we need to practice it daily.',
#  'I am using a Udemy course to learn NLP.',
#  'It is a great course for beginners.']

# %% [markdown]
# _Paragraphs --> Words_
#
# _Sentence --> Words_

# %%
words = word_tokenize(corpus)

# %%
for sentence in sentences:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'Welcome', '!']
# ['This', 'is', 'umer', ',', 'learning', 'NLP', '.']
# ['To', 'learn', 'it', 'effectively', ',', 'we', 'need', 'to', 'practice', 'it', 'daily', '.']
# ['I', 'am', 'using', 'a', 'Udemy', 'course', 'to', 'learn', 'NLP', '.']
# ['It', 'is', 'a', 'great', 'course', 'for', 'beginners', '.']

# %%
wordpunct = wordpunct_tokenize(corpus)

# %%
tokenizer = TreebankWordTokenizer()
treebankwords = tokenizer.tokenize(corpus)
