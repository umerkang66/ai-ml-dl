# %%
words = [
    "eat", "eating", "eats", "eaten", "ate",
    "run", "running", "runs", "runner",
    "play", "playing", "played", "player", "plays",
    "study", "studies", "studying", "studied",
    "connect", "connected", "connecting", "connection", "connections",
    "happy", "happiness", "happier", "happiest",
    "compute", "computer", "computing", "computation", "computes",
    "argue", "arguing", "argued", "argument", "arguably",
    "fly", "flies", "flying", "flew",
    "organize", "organizing", "organized", "organization"
]

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('going', pos='v')
# Out:
# 'go'

# %%
for word in words:
    print(f"{word} : {lemmatizer.lemmatize(word, pos='v')}")
# Out:
# eat : eat
# eating : eat
# eats : eat
# eaten : eat
# ate : eat
# run : run
# running : run
# runs : run
# runner : runner
# play : play
# playing : play
# played : play
# player : player
# plays : play
# study : study
# studies : study
# studying : study
# studied : study
# connect : connect
# connected : connect
# connecting : connect
# connection : connection
# connections : connections
# happy : happy
# happiness : happiness
# happier : happier
# happiest : happiest
# compute : compute
# computer : computer
# computing : compute
# computation : computation
# computes : compute
# argue : argue
# arguing : argue
# argued : argue
# argument : argument
# arguably : arguably
# fly : fly
# flies : fly
# flying : fly
# flew : fly
# organize : organize
# organizing : organize
# organized : organize
# organization : organization
