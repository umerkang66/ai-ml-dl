# %%
import cv2

# %%
image = cv2.imread("images/butterfly.jpg")

# %%
cv2.imshow("Image Window", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_new = image + 30
cv2.imwrite("images/butterfly_new.jpg", image_new)
# Out:
# True
